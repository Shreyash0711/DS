# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('churn_modelling.csv')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail()
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.columns
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.groupby('Geography')['Balance'].mean()
# Out:
# Geography
# France      62092.636516
# Germany    119730.116134
# Spain       61818.147763
# Name: Balance, dtype: float64

# %%
df.sort_values('Age')
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 3512       3513    15657779       Boylan          806     Spain    Male   18
# 1678       1679    15569178    Kharlamov          570    France  Female   18
# 3517       3518    15757821      Burgess          771     Spain    Male   18
# 9520       9521    15673180  Onyekaozulu          727   Germany  Female   18
# 2021       2022    15795519     Vasiliev          716   Germany  Female   18
# ...         ...         ...          ...          ...       ...     ...  ...
# 3387       3388    15798024         Lori          537   Germany    Male   84
# 3033       3034    15578006          Yao          787    France  Female   85
# 2458       2459    15813303      Rearick          513     Spain    Male   88
# 6759       6760    15660878        T'ien          705    France    Male   92
# 6443       6444    15764927       Rogova          753    France    Male   92
#
# ...

# %%
df.T
# Out:
#                       0          1          2         3          4     \
# RowNumber                1          2          3         4          5
# CustomerId        15634602   15647311   15619304  15701354   15737888
# Surname           Hargrave       Hill       Onio      Boni   Mitchell
# CreditScore            619        608        502       699        850
# Geography           France      Spain     France    France      Spain
# Gender              Female     Female     Female    Female     Female
# Age                     42         41         42        39         43
# Tenure                   2          1          8         1          2
# Balance                0.0   83807.86   159660.8       0.0  125510.82
# NumOfProducts            1          1          3         2          1
# HasCrCard                1          0          1         0          1
# IsActiveMember           1          1          0         0          1
# ...

# %%
df['Balance'].head()
# Out:
# 0         0.00
# 1     83807.86
# 2    159660.80
# 3         0.00
# 4    125510.82
# Name: Balance, dtype: float64

# %%
df.Balance.head()
# Out:
# 0         0.00
# 1     83807.86
# 2    159660.80
# 3         0.00
# 4    125510.82
# Name: Balance, dtype: float64

# %%
a = df.columns

# %%
df['new_balance'] = df.Balance + 1000

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_balance
# 0        101348.88       1      1000.00
# 1        112542.58       0     84807.86
# ...

# %%
df['random'] = 'good day'

# %%
df.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  new_balance    random
# 0        101348.88       1      1000.00  good day
# 1        112542.58       0     84807.86  good day
# ...

# %%
df[10:13]
# Out:
#     RowNumber  CustomerId  Surname  CreditScore Geography  Gender  Age  \
# 10         11    15767821   Bearce          528    France    Male   31
# 11         12    15737173  Andrews          497     Spain    Male   24
# 12         13    15632264      Kay          476    France  Female   34
#
#     Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 10       6  102016.72              2          0               0
# 11       3       0.00              2          1               0
# 12      10       0.00              2          1               0
#
#     EstimatedSalary  Exited  new_balance    random
# 10         80181.12       0    103016.72  good day
# 11         76390.01       0      1000.00  good day
# 12         26260.98       0      1000.00  good day

# %%
new_df = df[df.Age <20]

# %%
df.isnull().sum().value_counts()
# Out:
# 0    16
# dtype: int64

# %%
df.shape
# Out:
# (10000, 16)

# %%
df.fillna(df.Balance.mean())
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.pop('random')
# Out:
# 0       good day
# 1       good day
# 2       good day
# 3       good day
# 4       good day
#           ...
# 9995    good day
# 9996    good day
# 9997    good day
# 9998    good day
# 9999    good day
# Name: random, Length: 10000, dtype: object

# %%
df.head(1)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
#
#    Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# 0       2      0.0              1          1               1        101348.88
#
#    Exited  new_balance
# 0       1       1000.0

# %%
df.pop('CustomerId')
# Out:
# 0       15634602
# 1       15647311
# 2       15619304
# 3       15701354
# 4       15737888
#           ...
# 9995    15606229
# 9996    15569892
# 9997    15584532
# 9998    15682355
# 9999    15628319
# Name: CustomerId, Length: 10000, dtype: int64

# %%
df.drop('RowNumber', axis = 1)
# Out:
#         Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0      Hargrave          619    France  Female   42       2       0.00
# 1          Hill          608     Spain  Female   41       1   83807.86
# 2          Onio          502    France  Female   42       8  159660.80
# 3          Boni          699    France  Female   39       1       0.00
# 4      Mitchell          850     Spain  Female   43       2  125510.82
# ...         ...          ...       ...     ...  ...     ...        ...
# 9995   Obijiaku          771    France    Male   39       5       0.00
# 9996  Johnstone          516    France    Male   35      10   57369.61
# 9997        Liu          709    France  Female   36       7       0.00
# 9998  Sabbatini          772   Germany    Male   42       3   75075.31
# 9999     Walker          792    France  Female   28       4  130142.79
#
#       NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# ...

# %%
df['Balance'].apply(np.sqrt)
# Out:
# 0         0.000000
# 1       289.495872
# 2       399.575775
# 3         0.000000
# 4       354.275063
#            ...
# 9995      0.000000
# 9996    239.519540
# 9997      0.000000
# 9998    273.998741
# 9999    360.753087
# Name: Balance, Length: 10000, dtype: float64

# %%
df.Age.dropna()
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %%
new_df.head(1)
# Out:
#     RowNumber  CustomerId   Surname  CreditScore Geography Gender  Age  \
# 57         58    15647091  Endrizzi          725   Germany   Male   19
#
#     Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 57       0  75888.2              1          0               0
#
#     EstimatedSalary  Exited  new_balance    random
# 57         45613.75       0      76888.2  good day

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#       RowNumber    Surname  CreditScore Geography  Gender  Age  Tenure  \
# 0             1   Hargrave          619    France  Female   42       2
# 1             2       Hill          608     Spain  Female   41       1
# 2             3       Onio          502    France  Female   42       8
# 3             4       Boni          699    France  Female   39       1
# 4             5   Mitchell          850     Spain  Female   43       2
# ...         ...        ...          ...       ...     ...  ...     ...
# 9995       9996   Obijiaku          771    France    Male   39       5
# 9996       9997  Johnstone          516    France    Male   35      10
# 9997       9998        Liu          709    France  Female   36       7
# 9998       9999  Sabbatini          772   Germany    Male   42       3
# 9999      10000     Walker          792    France  Female   28       4
#
#         Balance  NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  \
# ...

# %%
s = pd.Series(list("abcdef"),index = [49,48,47,0,1,2])
s
# Out:
# 49    a
# 48    b
# 47    c
# 0     d
# 1     e
# 2     f
# dtype: object

# %%
pd.DataFrame(s)
# Out:
#     0
# 49  a
# 48  b
# 47  c
# 0   d
# 1   e
# 2   f

# %%
s.loc[0]
# Out:
# 'd'

# %%
s.iloc[0]
# Out:
# 'a'

# %%
s.loc[0:2]
# Out:
# 0    d
# 1    e
# 2    f
# dtype: object

# %%
s.iloc[0:3]
# Out:
# 49    a
# 48    b
# 47    c
# dtype: object

# %%
df.head()
# Out:
#    RowNumber   Surname  CreditScore Geography  Gender  Age  Tenure    Balance  \
# 0          1  Hargrave          619    France  Female   42       2       0.00
# 1          2      Hill          608     Spain  Female   41       1   83807.86
# 2          3      Onio          502    France  Female   42       8  159660.80
# 3          4      Boni          699    France  Female   39       1       0.00
# 4          5  Mitchell          850     Spain  Female   43       2  125510.82
#
#    NumOfProducts  HasCrCard  IsActiveMember  EstimatedSalary  Exited  \
# 0              1          1               1        101348.88       1
# 1              1          0               1        112542.58       0
# 2              3          1               0        113931.57       1
# 3              2          0               0         93826.63       0
# 4              1          1               1         79084.10       0
#
#    new_balance
# 0      1000.00
# 1     84807.86
# 2    160660.80
# ...

# %%
df.groupby('Gender')['CreditScore'].mean()
# Out:
# Gender
# Female    650.831389
# Male      650.276892
# Name: CreditScore, dtype: float64

# %%
df.groupby

# %%
df.groupby('Geography')['RowNumber'].count()
# Out:
# Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: RowNumber, dtype: int64

# %%
df.groupby('Gender')['Geography'].agg(lambda x : x.mode().iloc[0])
# Out:
# Gender
# Female    France
# Male      France
# Name: Geography, dtype: object

# %%
a = df.groupby('Gender')

# %%
#Average Credit Score by Gender
df.groupby('Gender')['CreditScore'].mean()
# Out:
# Gender
# Female    650.831389
# Male      650.276892
# Name: CreditScore, dtype: float64

# %%
#Number of Exited customers by Gender
df.groupby('Gender')['Exited'].sum()
# Out:
# Gender
# Female    1139
# Male       898
# Name: Exited, dtype: int64

# %%
#Average Balance of customers who exited vs not
df.groupby('Exited')['Balance'].mean()
# Out:
# Exited
# 0    72745.296779
# 1    91108.539337
# Name: Balance, dtype: float64

# %%
#Average Tenure and Age by Geography
df.groupby('Geography')['Tenure','Age'].mean()
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#              Tenure        Age
# Geography
# France     5.004587  38.511767
# Germany    5.009964  39.771622
# Spain      5.032297  38.890997

# %%
#Churn rate by Geography
df.groupby('Geography')['Exited'].sum()
# Out:
# Geography
# France     810
# Germany    814
# Spain      413
# Name: Exited, dtype: int64

# %%
#Average new balance by Gender and Geography
df.groupby(['Gender','Geography'])['Balance'].mean()
# Out:
# Gender  Geography
# Female  France        60322.670159
#         Germany      119145.966471
#         Spain         59862.092534
# Male    France        63546.284875
#         Germany      120259.668222
#         Spain         63352.833746
# Name: Balance, dtype: float64

# %%
#Most common number of products per country
df.groupby('Geography')['NumOfProducts'].agg(lambda x : x.mode().iloc[0])
# Out:
# Geography
# France     1
# Germany    1
# Spain      1
# Name: NumOfProducts, dtype: int64

# %%
#Count of Credit Card holders by Geography
df.groupby('Geography')['HasCrCard'].sum()
# Out:
# Geography
# France     3543
# Germany    1791
# Spain      1721
# Name: HasCrCard, dtype: int64

# %%
#Churn rate by Geography
df.groupby('Geography')['Exited'].sum()
# Out:
# Geography
# France     810
# Germany    814
# Spain      413
# Name: Exited, dtype: int64

# %%
#Churn rate of Active vs Inactive Members
df.groupby('IsActiveMember')['Exited'].sum()
# Out:
# IsActiveMember
# 0    1302
# 1     735
# Name: Exited, dtype: int64

# %%
import pandas as pd
import dash
from dash import dcc, html
from dash.dependencies import Input, Output
import plotly.express as px

# Sample Data
df = pd.read_csv('churn_modelling.csv')  # Replace with actual path

# Initialize Dash app
app = dash.Dash(__name__)
app.title = "Bank Customer Dashboard"

# Layout
app.layout = html.Div([
    html.H1("Customer Churn Dashboard", style={'textAlign': 'center'}),

    # Dropdown for filtering by Geography
    html.Div([
        html.Label("Select Country:"),
        dcc.Dropdown(
            id='geo-dropdown',
            options=[{'label': geo, 'value': geo} for geo in df['Geography'].unique()],
            value='France',
            clearable=False
        )
    ], style={'width': '30%', 'margin': 'auto'}),

    # Graphs
    html.Div([
        dcc.Graph(id='churn-by-geo'),
        dcc.Graph(id='credit-by-gender'),
        dcc.Graph(id='balance-pie'),
        dcc.Graph(id='age-dist')
    ])
])

# Callbacks
@app.callback(
    Output('churn-by-geo', 'figure'),
    Output('credit-by-gender', 'figure'),
    Output('balance-pie', 'figure'),
    Output('age-dist', 'figure'),
    Input('geo-dropdown', 'value')
)
def update_graphs(selected_geo):
    churn_fig = px.bar(
        df.groupby('Geography')['Exited'].mean().reset_index(),
        x='Geography', y='Exited',
        title='Churn Rate by Geography'
    )

    credit_fig = px.bar(
        df.groupby('Gender')['CreditScore'].mean().reset_index(),
        x='Gender', y='CreditScore',
        title='Average Credit Score by Gender',
        color='Gender'
    )

    balance_fig = px.pie(
        df, names='Exited', values='Balance',
        title='Balance Distribution by Churn Status',
        hole=0.4,
        labels={0: 'Stayed', 1: 'Exited'}
    )

    age_fig = px.histogram(
        df[df['Geography'] == selected_geo],
        x='Age',
        nbins=20,
        title=f'Age Distribution in {selected_geo}'
    )

    return churn_fig, credit_fig, balance_fig, age_fig

# Run app
if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
pip install dash
# Out:
# ...
#   Using cached dash-2.15.0-py3-none-any.whl.metadata (11 kB)
# ...
# Using cached dash-2.15.0-py3-none-any.whl (10.2 MB)
# Using cached dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Using cached dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Using cached dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.

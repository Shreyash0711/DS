# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt 
from scipy import stats 
import numpy as np 
import seaborn as sns

# %%
df=pd.read_csv("StudentPerformance.csv")

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        80.0           90.0           70.0               77            2018
# 1        70.0           77.0           76.0               85            2018
# 2        62.0           88.0           68.0               92            2019
# 3        94.0           84.0           71.0               78            2019
# 4        78.0           81.0           62.0              100            2020
#
#    Placement_Offer_Count
# 0                      2
# 1                      3
# 2                      3
# 3                      2
# 4                      3

# %%
df.isnull().sum()
# Out:
# Math_score               1
# Reading_score            1
# Writing_score            1
# Placement_score          0
# Club_Join_Date           0
# Placement_Offer_Count    0
# dtype: int64

# %%
series1=pd.isnull(df['Reading_score'])

# %%
df[series1]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 28        80.0            NaN           61.0              100            2020
#
#     Placement_Offer_Count
# 28                      3

# %%
series2=pd.isnull(df['Writing_score'])

# %%
df[series2]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 19        70.0           82.0            NaN               89            2020
#
#     Placement_Offer_Count
# 19                      3

# %%
df.fillna(0)
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df[series1]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 28        80.0            NaN           61.0              100            2020
#
#     Placement_Offer_Count
# 28                      3

# %%
df.isnull().sum()
# Out:
# Math_score               1
# Reading_score            1
# Writing_score            1
# Placement_score          0
# Club_Join_Date           0
# Placement_Offer_Count    0
# dtype: int64

# %%
 df['Math_score']= df['Math_score'].fillna (df['Math_score'].mean())

# %%
df['Math_score']
# Out:
# 0      80.000000
# 1      70.000000
# 2      62.000000
# 3      94.000000
# 4      78.000000
# 5      77.000000
# 6      77.000000
# 7      62.000000
# 8      79.000000
# 9      63.000000
# 10     66.000000
# 11     69.000000
# 12     80.000000
# 13     66.000000
# 14     64.000000
# 15     78.000000
# 16     61.000000
# 17    180.000000
# 18     80.000000
# 19     70.000000
# 20     69.000000
# 21     71.000000
# 22     71.000000
# 23     61.000000
# 24     75.103448
# 25     76.000000
# 26     68.000000
# 27     61.000000
# 28     80.000000
# 29     65.000000
# Name: Math_score, dtype: float64

# %%
df['Reading_score']= df['Reading_score'].fillna(df['Reading_score'].median())

# %%
df['Reading_score']
# Out:
# 0      90.0
# 1      77.0
# 2      88.0
# 3      84.0
# 4      81.0
# 5     200.0
# 6      75.0
# 7      80.0
# 8      88.0
# 9      94.0
# 10     79.0
# 11     78.0
# 12     88.0
# 13     90.0
# 14     90.0
# 15     86.0
# 16     95.0
# 17     82.0
# 18     90.0
# 19     82.0
# 20     83.0
# 21     81.0
# 22     91.0
# 23     78.0
# 24     81.0
# 25     83.0
# 26     87.0
# 27     75.0
# 28     83.0
# 29     78.0
# Name: Reading_score, dtype: float64

# %%
df[ 'Writing_score']= df['Writing_score'].fillna(df['Writing_score'].mean())

# %%
 df['Writing_score']
# Out:
# 0     70.00000
# 1     76.00000
# 2     68.00000
# 3     71.00000
# 4     62.00000
# 5     73.00000
# 6     65.00000
# 7     63.00000
# 8     65.00000
# 9     73.00000
# 10    77.00000
# 11    77.00000
# 12    77.00000
# 13    72.00000
# 14    67.00000
# 15    64.00000
# 16    64.00000
# 17    76.00000
# 18    74.00000
# 19    69.62069
# 20    74.00000
# 21    63.00000
# 22    61.00000
# 23    69.00000
# 24    66.00000
# 25    79.00000
# 26    76.00000
# 27    63.00000
# 28    61.00000
# 29    73.00000
# Name: Writing_score, dtype: float64

# %%
df['Writing_score'].mode
# Out:
# <bound method Series.mode of 0     70.00000
# 1     76.00000
# 2     68.00000
# 3     71.00000
# 4     62.00000
# 5     73.00000
# 6     65.00000
# 7     63.00000
# 8     65.00000
# 9     73.00000
# 10    77.00000
# 11    77.00000
# 12    77.00000
# 13    72.00000
# 14    67.00000
# 15    64.00000
# 16    64.00000
# 17    76.00000
# 18    74.00000
# 19    69.62069
# 20    74.00000
# 21    63.00000
# 22    61.00000
# 23    69.00000
# 24    66.00000
# 25    79.00000
# 26    76.00000
# 27    63.00000
# 28    61.00000
# 29    73.00000
# Name: Writing_score, dtype: float64>

# %%
col=['Math_score', 'Reading_score', 'Writing_score', 'Placement_score']

# %%
df.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
z=stats.zscore(df['Math_score'])

# %%
z
# Out:
# 0     2.335694e-01
# 1    -2.434386e-01
# 2    -6.250450e-01
# 3     9.013807e-01
# 4     1.381678e-01
# 5     9.046704e-02
# 6     9.046704e-02
# 7    -6.250450e-01
# 8     1.858686e-01
# 9    -5.773442e-01
# 10   -4.342418e-01
# 11   -2.911394e-01
# 12    2.335694e-01
# 13   -4.342418e-01
# 14   -5.296434e-01
# 15    1.381678e-01
# 16   -6.727458e-01
# 17    5.003650e+00
# 18    2.335694e-01
# 19   -2.434386e-01
# 20   -2.911394e-01
# 21   -1.957378e-01
# 22   -1.957378e-01
# 23   -6.727458e-01
# 24   -6.778692e-16
# 25    4.276624e-02
# 26   -3.388402e-01
# 27   -6.727458e-01
# 28    2.335694e-01
# 29   -4.819426e-01
# Name: Math_score, dtype: float64

# %%
threshold=3

# %%
sample_outliers=np.where(z>threshhold)

# %%
sample_outliers
# Out:
# (array([17], dtype=int64),)

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   30.000000      30.000000      30.000000        30.000000
# mean    75.103448      87.900000      69.620690        85.633333
# std     21.322394      21.871648       5.634951         8.833648
# min     61.000000      75.000000      61.000000        75.000000
# 25%     65.250000      80.250000      64.250000        77.250000
# 50%     70.500000      83.000000      69.810345        82.000000
# 75%     78.000000      89.500000      74.000000        93.000000
# max    180.000000     200.000000      79.000000       100.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count       30.000000              30.000000
# mean      2019.466667               2.433333
# std          0.899553               0.568321
# min       2018.000000               1.000000
# 25%       2019.000000               2.000000
# 50%       2020.000000               2.000000
# 75%       2020.000000               3.000000
# ...

# %%
q1=df.Math_score.quantile(0.25)

# %%
q1
# Out:
# 65.25

# %%
q2=df.Math_score.quantile(0.75)

# %%
q2
# Out:
# 78.0

# %%
IQR=q2-q1

# %%
IQR
# Out:
# 12.75

# %%
lower_limit = q1-1.5*IQR

# %%
lower_limit
# Out:
# 46.125

# %%
upper_limit = q1+1.5*IQR

# %%
upper_limit
# Out:
# 84.375

# %%
sample_outliers=df['Math_score'][(df['Math_score']>upper_limit)| (df['Math_score']<lower_limit)]

# %%
sample_outliers
# Out:
# 3      94.0
# 17    180.0
# Name: Math_score, dtype: float64

# %%
mean1=df['Math_score'].mean()

# %%
mean1
# Out:
# 75.10344827586208

# %%
df['Math_score']=np.where((df['Math_score']>upper_limit) | (df['Math_score']<lower_limit), mean1, df['Math_score'])

# %%
df['Math_score']
# Out:
# 0     80.000000
# 1     70.000000
# 2     62.000000
# 3     75.103448
# 4     78.000000
# 5     77.000000
# 6     77.000000
# 7     62.000000
# 8     79.000000
# 9     63.000000
# 10    66.000000
# 11    69.000000
# 12    80.000000
# 13    66.000000
# 14    64.000000
# 15    78.000000
# 16    61.000000
# 17    75.103448
# 18    80.000000
# 19    70.000000
# 20    69.000000
# 21    71.000000
# 22    71.000000
# 23    61.000000
# 24    75.103448
# 25    76.000000
# 26    68.000000
# 27    61.000000
# 28    80.000000
# 29    65.000000
# Name: Math_score, dtype: float64

# %%
df_scaled = df.copy()

# %%
for column in df_scaled.columns:
    df_scaled[column] = (df_scaled[column].min()) / (df_scaled[column].max() - df_scaled[column].min())

# %%
df_scaled
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0     3.210526            0.6       3.388889              3.0      672.666667
# 1     3.210526            0.6       3.388889              3.0      672.666667
# 2     3.210526            0.6       3.388889              3.0      672.666667
# 3     3.210526            0.6       3.388889              3.0      672.666667
# 4     3.210526            0.6       3.388889              3.0      672.666667
# 5     3.210526            0.6       3.388889              3.0      672.666667
# 6     3.210526            0.6       3.388889              3.0      672.666667
# 7     3.210526            0.6       3.388889              3.0      672.666667
# 8     3.210526            0.6       3.388889              3.0      672.666667
# 9     3.210526            0.6       3.388889              3.0      672.666667
# 10    3.210526            0.6       3.388889              3.0      672.666667
# ...

# %%
mean1
# Out:
# 75.10344827586208

# %%
sns.set_style('whitegrid')
sns.displot(df['Math_score'])

# %%
sns.set_style('whitegrid')
sns.distplot(df['Reading_score'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Reading_score', ylabel='Density'>

# %%
sns.set_style('whitegrid')
sns.distplot(df['Math_score'])
# Out:
# C:\Users\ADMIN\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Math_score', ylabel='Density'>

# %%
dist = sns.displot(data=df, x='Reading_score',col='Math_score')
dist.fig.subplots_adjust(top=0.92)
plt.show()
